# %% [markdown]
# # Herramientas necesarias

# %%
from google.colab import drive
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
# MOntar el drive
drive.mount("/content/gdrive")

# %cd "/content/gdrive/MyDrive/Procesamiento de imagenes/Proyecto Final/Depth-Estimation-with-StereoThermal-Images/Datos"
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/MyDrive/Procesamiento de imagenes/Proyecto Final/Depth-Estimation-with-StereoThermal-Images/Datos

# %%
image_left = cv2.imread("stereo_thermal_14_left/1630141488005503289.png", cv2.IMREAD_ANYDEPTH)
image_right = cv2.imread("stereo_thermal_14_right/1630141488990959675.png", cv2.IMREAD_ANYDEPTH)
plt.figure(figsize=[15,18])
plt.subplot(121)
plt.imshow(image_left)
plt.title("Imagen de la izquierda")
plt.subplot(122)
plt.imshow(image_right)
plt.title("Imagen de la derecha")
plt.show()

# %%
print("Imagen left")
print("Valor maximo = ", image_left.max(), "Valor minimo = ", image_left.min())
print("IMagen right")
print("Valor maximo = ", image_right.max(), "Valor minimo = ", image_right.min())
# Out:
# Imagen left
# Valor maximo =  4988 Valor minimo =  2518
# IMagen right
# Valor maximo =  4840 Valor minimo =  2722
