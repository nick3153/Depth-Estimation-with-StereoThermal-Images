# %% [markdown]
# # Clonar el proyecto
# *Nota: Asegurarse de estar trabajando con la GPU.*

# %%
# !git clone https://github.com/gangweix/Fast-ACVNet.git
# !git clone https://github.com/nick3153/Depth-Estimation-with-StereoThermal-Images.git
# %cd Fast-ACVNet
# Out:
# Cloning into 'Fast-ACVNet'...
# remote: Enumerating objects: 213, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 213 (delta 46), reused 31 (delta 31), pack-reused 152 (from 1)
# Receiving objects: 100% (213/213), 86.10 MiB | 17.52 MiB/s, done.
# Resolving deltas: 100% (96/96), done.
# Updating files: 100% (50/50), done.
# Cloning into 'Depth-Estimation-with-StereoThermal-Images'...
# remote: Enumerating objects: 6149, done.
# remote: Counting objects: 100% (2/2), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 6149 (delta 1), reused 0 (delta 0), pack-reused 6147 (from 3)
# Receiving objects: 100% (6149/6149), 1.68 GiB | 31.33 MiB/s, done.
# Resolving deltas: 100% (60/60), done.
# Updating files: 100% (152/152), done.
# /content/Fast-ACVNet

# %% [markdown]
# # Instalar dependencias necesarias

# %%
# !pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu113
# !pip install opencv-python
# !pip install scikit-image
# !pip install tensorboard
# !pip install matplotlib
# !pip install tqdm
# !pip install timm==0.5.4
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 118.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 91.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 61.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 91.4 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (2.0.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2.0.2)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (1.15.3)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (3.4.2)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (11.2.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2025.5.21)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (0.4)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard) (1.71.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard) (3.8)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorboard) (24.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard) (5.29.4)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard) (75.2.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.11/dist-packages (from tensorboard) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard) (3.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Collecting timm==0.5.4
#   Downloading timm-0.5.4-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.11/dist-packages (from timm==0.5.4) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from timm==0.5.4) (0.21.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.5.4) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.5.4) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.5.4) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.5.4) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.5.4) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.5.4) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.5.4) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.5.4) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.5.4) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.5.4) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.5.4) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.5.4) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.5.4) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.5.4) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.5.4) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.5.4) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.5.4) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.5.4) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.5.4) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.4->timm==0.5.4) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.4->timm==0.5.4) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision->timm==0.5.4) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision->timm==0.5.4) (11.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.4->timm==0.5.4) (3.0.2)
# Downloading timm-0.5.4-py3-none-any.whl (431 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.5/431.5 kB 15.9 MB/s eta 0:00:00
# Installing collected packages: timm
#   Attempting uninstall: timm
#     Found existing installation: timm 1.0.15
#     Uninstalling timm-1.0.15:
#       Successfully uninstalled timm-1.0.15
# Successfully installed timm-0.5.4

# %% [markdown]
# # Código

# %%
#@title Montar el drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#@title Funciones necesarias
from PIL import Image
import numpy as np
import cv2
from PIL import Image

def normalize(img):
    image = ((img - img.min()) / (img.max() - img.min())) * 255.0
    return image.astype(np.uint8)

def intensity_binding(img, lower_percentile:int=1, upper_percentile:int=99):
    # Calcular los percentiles
    low = np.percentile(img, lower_percentile)
    high = np.percentile(img, upper_percentile)

    # Recortar al rango [low, high]
    img_clipped = np.clip(img, low, high)

    img_norm = normalize(img_clipped)

    return img_norm

def apply_CLAHE(img):
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    return clahe.apply(img)

def bilateral_filtering(img):
    return cv2.bilateralFilter(img, d=5, sigmaColor=15, sigmaSpace=3)

def align_contrast(imgL, imgR):
    meanL = np.mean(imgL)
    meanR = np.mean(imgR)

    if meanR < meanL:
      imageR = imgR * (meanL/meanR)
      return imgL, imageR
    elif meanL < meanR:
      imageL = imgL * (meanR/meanL)
      return imageL, imgR

    return imgL, imgR

def preprocess_thermal_image(img):
    if np.max(img) < 35000:
      image = normalize(img)
    else:
      # Eliminar outlayers
      image = intensity_binding(img)

    # Ecualizacion del histograma con clahe
    image = apply_CLAHE(image)

    # Eliminacion de ruido
    image = bilateral_filtering(image)

    return image.astype(np.uint8)

def preprocess_images(imgL, imgR):
    imageL = preprocess_thermal_image(imgL)
    imageR = preprocess_thermal_image(imgR)

    imageL, imageR = align_contrast(imageL, imageR)

    return Image.fromarray(imageL.astype(np.uint8)), Image.fromarray(imageR.astype(np.uint8))

def depth_to_disparity(depth, focal_length = 406.33233091474426, baseline = 0.2458492526627874):
    # Evitar división por cero
    depth = np.clip(depth, a_min=1e-6, a_max=None)
    disparity = (focal_length * baseline) / depth
    return disparity

# %%
import os
import torch
from torch.utils.data import Dataset
from PIL import Image
import numpy as np
import cv2
import random
import torchvision.transforms as transforms

class ThermalStereoDataset(Dataset):
    def __init__(self, root_dir, domain='frick_2', split='train', training=True, crop_size=(512, 256)):
        self.training = training
        self.crop_w, self.crop_h = crop_size
        self.left_dir = os.path.join(root_dir, domain, split, 'img_left')
        self.right_dir = os.path.join(root_dir, domain, split, 'img_right')
        self.disp_dir = os.path.join(root_dir, domain, split, 'depth_filtered')

        self.left_images = sorted(os.listdir(self.left_dir))
        self.right_images = sorted(os.listdir(self.right_dir))
        self.disp_images = sorted(os.listdir(self.disp_dir))

        self.transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ])

    def replicate_to_3_channels(self, img):
        img_np = np.array(img)
        if img_np.ndim == 2:
            img_np = np.stack([img_np]*3, axis=-1)
        return Image.fromarray(img_np.astype(np.uint8))

    def __len__(self):
        return len(self.left_images)

    def __getitem__(self, idx):
        # Cargar imágenes
        left_path = os.path.join(self.left_dir, self.left_images[idx])
        right_path = os.path.join(self.right_dir, self.right_images[idx])
        depth_path = os.path.join(self.disp_dir, self.disp_images[idx])

        left_img = cv2.imread(left_path, cv2.IMREAD_UNCHANGED)
        right_img = cv2.imread(right_path, cv2.IMREAD_UNCHANGED)
        depth = np.array(Image.open(depth_path)).astype(np.float32) / 1000.0

        # Aplicar procesado a las imagenes
        left_img, right_img = preprocess_images(left_img, right_img)

        # Calcular el mapa de disparidad
        disparity = depth_to_disparity(depth)

        # Gradiente
        left_np = np.array(left_img)
        dx = cv2.Sobel(left_np, cv2.CV_32F, 1, 0, ksize=3)
        dy = cv2.Sobel(left_np, cv2.CV_32F, 0, 1, ksize=3)
        dxy = np.sqrt(dx**2 + dy**2)
        dxy = dxy / (np.max(dxy) + 1e-5)

        # Replicar a 3 canales
        left_img = self.replicate_to_3_channels(left_img)
        right_img = self.replicate_to_3_channels(right_img)

        if self.training:
            w, h = left_img.size
            x1 = random.randint(0, w - self.crop_w)
            y1 = random.randint(0, h - self.crop_h)

            # Crop
            left_img = left_img.crop((x1, y1, x1 + self.crop_w, y1 + self.crop_h))
            right_img = right_img.crop((x1, y1, x1 + self.crop_w, y1 + self.crop_h))
            disparity = disparity[y1:y1 + self.crop_h, x1:x1 + self.crop_w]
            gradient_map = dxy[y1:y1 + self.crop_h, x1:x1 + self.crop_w]

            # Disparidad downsampled
            disparity_low = cv2.resize(disparity, (self.crop_w//4, self.crop_h//4), interpolation=cv2.INTER_NEAREST)
            disparity_low_r8 = cv2.resize(disparity, (self.crop_w//8, self.crop_h//8), interpolation=cv2.INTER_NEAREST)

            # Aplicar transformaciones
            left_img = self.transform(left_img)
            right_img = self.transform(right_img)
            disparity = torch.from_numpy(disparity).float()
            gradient_map = torch.from_numpy(gradient_map).float()
            disparity_low = torch.from_numpy(disparity_low).float()
            disparity_low_r8 = torch.from_numpy(disparity_low_r8).float()

            return {
                "left": left_img,
                "right": right_img,
                "disparity": disparity,
                "gradient_map": gradient_map,
                "disparity_low": disparity_low,
                "disparity_low_r8": disparity_low_r8}

        else:
          w, h = left_img.size
          crop_w, crop_h = 640, 512

          left_img = left_img.crop((w - crop_w, h - crop_h, w, h))
          right_img = right_img.crop((w - crop_w, h - crop_h, w, h))
          disparity = disparity[h - crop_h:h, w - crop_w: w]
          gradient_map = dxy[h - crop_h:h, w - crop_w: w]
          disparity_low = cv2.resize(disparity, (crop_w//4, crop_h//4), interpolation=cv2.INTER_NEAREST)

          left_img = self.transform(left_img)
          right_img = self.transform(right_img)
          disparity = torch.from_numpy(disparity).float()
          gradient_map = torch.from_numpy(gradient_map).float()
          disparity_low = torch.from_numpy(disparity_low).float()

          return {"left": left_img,
                  "right": right_img,
                  "disparity": disparity,
                  "top_pad": 0,
                  "right_pad": 0,
                  "gradient_map":gradient_map,
                  "disparity_low":disparity_low}

# %%
import argparse
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0,1'
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data
from torch.autograd import Variable
import torchvision.utils as vutils
import torch.nn.functional as F
import numpy as np
import time
from models import __models__, model_loss_train, model_loss_test
from utils import *
from torch.utils.data import DataLoader
import gc
import cv2

# Optimizzar el funcionamiento de la GPU
cudnn.benchmark = True

# Establecer una semilla para reproducibilidad
torch.manual_seed(1)
torch.cuda.manual_seed(1)

# model, optimizer
model = __models__['Fast_ACVNet'](192, False)
model = nn.DataParallel(model)
model.cuda()

# Comprobar si hay capas congeladas
for name, param in model.named_parameters():
    print(f"Layer: {name}, Requires Gradient: {param.requires_grad}")
# Out:
# Downloading: "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-weights/mobilenetv2_100_ra-b33bc2c4.pth" to /root/.cache/torch/hub/checkpoints/mobilenetv2_100_ra-b33bc2c4.pth
# Layer: module.gamma, Requires Gradient: True
# Layer: module.beta, Requires Gradient: True
# Layer: module.feature.conv_stem.weight, Requires Gradient: True
# Layer: module.feature.bn1.weight, Requires Gradient: True
# Layer: module.feature.bn1.bias, Requires Gradient: True
# Layer: module.feature.block0.0.0.conv_dw.weight, Requires Gradient: True
# Layer: module.feature.block0.0.0.bn1.weight, Requires Gradient: True
# Layer: module.feature.block0.0.0.bn1.bias, Requires Gradient: True
# Layer: module.feature.block0.0.0.conv_pw.weight, Requires Gradient: True
# Layer: module.feature.block0.0.0.bn2.weight, Requires Gradient: True
# Layer: module.feature.block0.0.0.bn2.bias, Requires Gradient: True
# Layer: module.feature.block1.0.0.conv_pw.weight, Requires Gradient: True
# Layer: module.feature.block1.0.0.bn1.weight, Requires Gradient: True
# Layer: module.feature.block1.0.0.bn1.bias, Requires Gradient: True
# Layer: module.feature.block1.0.0.conv_dw.weight, Requires Gradient: True
# Layer: module.feature.block1.0.0.bn2.weight, Requires Gradient: True
# Layer: module.feature.block1.0.0.bn2.bias, Requires Gradient: True
# Layer: module.feature.block1.0.0.conv_pwl.weight, Requires Gradient: True
# Layer: module.feature.block1.0.0.bn3.weight, Requires Gradient: True
# Layer: module.feature.block1.0.0.bn3.bias, Requires Gradient: True
# Layer: module.feature.block1.0.1.conv_pw.weight, Requires Gradient: True
# Layer: module.feature.block1.0.1.bn1.weight, Requires Gradient: True
# Layer: module.feature.block1.0.1.bn1.bias, Requires Gradient: True
# Layer: module.feature.block1.0.1.conv_dw.weight, Requires Gradient: True
# Layer: module.feature.block1.0.1.bn2.weight, Requires Gradient: True
# Layer: module.feature.block1.0.1.bn2.bias, Requires Gradient: True
# Layer: module.feature.block1.0.1.conv_pwl.weight, Requires Gradient: True
# Layer: module.feature.block1.0.1.bn3.weight, Requires Gradient: True
# Layer: module.feature.block1.0.1.bn3.bias, Requires Gradient: True
# Layer: module.feature.block2.0.0.conv_pw.weight, Requires Gradient: True
# Layer: module.feature.block2.0.0.bn1.weight, Requires Gradient: True
# Layer: module.feature.block2.0.0.bn1.bias, Requires Gradient: True
# Layer: module.feature.block2.0.0.conv_dw.weight, Requires Gradient: True
# Layer: module.feature.block2.0.0.bn2.weight, Requires Gradient: True
# Layer: module.feature.block2.0.0.bn2.bias, Requires Gradient: True
# Layer: module.feature.block2.0.0.conv_pwl.weight, Requires Gradient: True
# Layer: module.feature.block2.0.0.bn3.weight, Requires Gradient: True
# Layer: module.feature.block2.0.0.bn3.bias, Requires Gradient: True
# Layer: module.feature.block2.0.1.conv_pw.weight, Requires Gradient: True
# Layer: module.feature.block2.0.1.bn1.weight, Requires Gradient: True
# Layer: module.feature.block2.0.1.bn1.bias, Requires Gradient: True
# Layer: module.feature.block2.0.1.conv_dw.weight, Requires Gradient: True
# Layer: module.feature.block2.0.1.bn2.weight, Requires Gradient: True
# Layer: module.feature.block2.0.1.bn2.bias, Requires Gradient: True
# Layer: module.feature.block2.0.1.conv_pwl.weight, Requires Gradient: True
# Layer: module.feature.block2.0.1.bn3.weight, Requires Gradient: True
# Layer: module.feature.block2.0.1.bn3.bias, Requires Gradient: True
# Layer: module.feature.block2.0.2.conv_pw.weight, Requires Gradient: True
# Layer: module.feature.block2.0.2.bn1.weight, Requires Gradient: True
# Layer: module.feature.block2.0.2.bn1.bias, Requires Gradient: True
# Layer: module.feature.block2.0.2.conv_dw.weight, Requires Gradient: True
# Layer: module.feature.block2.0.2.bn2.weight, Requires Gradient: True
# Layer: module.feature.block2.0.2.bn2.bias, Requires Gradient: True
# Layer: module.feature.block2.0.2.conv_pwl.weight, Requires Gradient: True
# Layer: module.feature.block2.0.2.bn3.weight, Requires Gradient: True
# Layer: module.feature.block2.0.2.bn3.bias, Requires Gradient: True
# Layer: module.feature.block3.0.0.conv_pw.weight, Requires Gradient: True
# Layer: module.feature.block3.0.0.bn1.weight, Requires Gradient: True
# Layer: module.feature.block3.0.0.bn1.bias, Requires Gradient: True
# Layer: module.feature.block3.0.0.conv_dw.weight, Requires Gradient: True
# Layer: module.feature.block3.0.0.bn2.weight, Requires Gradient: True
# Layer: module.feature.block3.0.0.bn2.bias, Requires Gradient: True
# Layer: module.feature.block3.0.0.conv_pwl.weight, Requires Gradient: True
# Layer: module.feature.block3.0.0.bn3.weight, Requires Gradient: True
# Layer: module.feature.block3.0.0.bn3.bias, Requires Gradient: True
# Layer: module.feature.block3.0.1.conv_pw.weight, Requires Gradient: True
# Layer: module.feature.block3.0.1.bn1.weight, Requires Gradient: True
# Layer: module.feature.block3.0.1.bn1.bias, Requires Gradient: True
# Layer: module.feature.block3.0.1.conv_dw.weight, Requires Gradient: True
# Layer: module.feature.block3.0.1.bn2.weight, Requires Gradient: True
# Layer: module.feature.block3.0.1.bn2.bias, Requires Gradient: True
# Layer: module.feature.block3.0.1.conv_pwl.weight, Requires Gradient: True
# Layer: module.feature.block3.0.1.bn3.weight, Requires Gradient: True
# Layer: module.feature.block3.0.1.bn3.bias, Requires Gradient: True
# Layer: module.feature.block3.0.2.conv_pw.weight, Requires Gradient: True
# Layer: module.feature.block3.0.2.bn1.weight, Requires Gradient: True
# Layer: module.feature.block3.0.2.bn1.bias, Requires Gradient: True
# Layer: module.feature.block3.0.2.conv_dw.weight, Requires Gradient: True
# Layer: module.feature.block3.0.2.bn2.weight, Requires Gradient: True
# Layer: module.feature.block3.0.2.bn2.bias, Requires Gradient: True
# Layer: module.feature.block3.0.2.conv_pwl.weight, Requires Gradient: True
# Layer: module.feature.block3.0.2.bn3.weight, Requires Gradient: True
# Layer: module.feature.block3.0.2.bn3.bias, Requires Gradient: True
# Layer: module.feature.block3.0.3.conv_pw.weight, Requires Gradient: True
# Layer: module.feature.block3.0.3.bn1.weight, Requires Gradient: True
# Layer: module.feature.block3.0.3.bn1.bias, Requires Gradient: True
# Layer: module.feature.block3.0.3.conv_dw.weight, Requires Gradient: True
# Layer: module.feature.block3.0.3.bn2.weight, Requires Gradient: True
# Layer: module.feature.block3.0.3.bn2.bias, Requires Gradient: True
# Layer: module.feature.block3.0.3.conv_pwl.weight, Requires Gradient: True
# Layer: module.feature.block3.0.3.bn3.weight, Requires Gradient: True
# Layer: module.feature.block3.0.3.bn3.bias, Requires Gradient: True
# Layer: module.feature.block3.1.0.conv_pw.weight, Requires Gradient: True
# Layer: module.feature.block3.1.0.bn1.weight, Requires Gradient: True
# Layer: module.feature.block3.1.0.bn1.bias, Requires Gradient: True
# Layer: module.feature.block3.1.0.conv_dw.weight, Requires Gradient: True
# Layer: module.feature.block3.1.0.bn2.weight, Requires Gradient: True
# Layer: module.feature.block3.1.0.bn2.bias, Requires Gradient: True
# Layer: module.feature.block3.1.0.conv_pwl.weight, Requires Gradient: True
# Layer: module.feature.block3.1.0.bn3.weight, Requires Gradient: True
# Layer: module.feature.block3.1.0.bn3.bias, Requires Gradient: True
# Layer: module.feature.block3.1.1.conv_pw.weight, Requires Gradient: True
# Layer: module.feature.block3.1.1.bn1.weight, Requires Gradient: True
# Layer: module.feature.block3.1.1.bn1.bias, Requires Gradient: True
# Layer: module.feature.block3.1.1.conv_dw.weight, Requires Gradient: True
# Layer: module.feature.block3.1.1.bn2.weight, Requires Gradient: True
# Layer: module.feature.block3.1.1.bn2.bias, Requires Gradient: True
# Layer: module.feature.block3.1.1.conv_pwl.weight, Requires Gradient: True
# Layer: module.feature.block3.1.1.bn3.weight, Requires Gradient: True
# Layer: module.feature.block3.1.1.bn3.bias, Requires Gradient: True
# Layer: module.feature.block3.1.2.conv_pw.weight, Requires Gradient: True
# Layer: module.feature.block3.1.2.bn1.weight, Requires Gradient: True
# Layer: module.feature.block3.1.2.bn1.bias, Requires Gradient: True
# Layer: module.feature.block3.1.2.conv_dw.weight, Requires Gradient: True
# Layer: module.feature.block3.1.2.bn2.weight, Requires Gradient: True
# Layer: module.feature.block3.1.2.bn2.bias, Requires Gradient: True
# Layer: module.feature.block3.1.2.conv_pwl.weight, Requires Gradient: True
# Layer: module.feature.block3.1.2.bn3.weight, Requires Gradient: True
# Layer: module.feature.block3.1.2.bn3.bias, Requires Gradient: True
# Layer: module.feature.block4.0.0.conv_pw.weight, Requires Gradient: True
# Layer: module.feature.block4.0.0.bn1.weight, Requires Gradient: True
# Layer: module.feature.block4.0.0.bn1.bias, Requires Gradient: True
# Layer: module.feature.block4.0.0.conv_dw.weight, Requires Gradient: True
# Layer: module.feature.block4.0.0.bn2.weight, Requires Gradient: True
# Layer: module.feature.block4.0.0.bn2.bias, Requires Gradient: True
# Layer: module.feature.block4.0.0.conv_pwl.weight, Requires Gradient: True
# Layer: module.feature.block4.0.0.bn3.weight, Requires Gradient: True
# Layer: module.feature.block4.0.0.bn3.bias, Requires Gradient: True
# Layer: module.feature.block4.0.1.conv_pw.weight, Requires Gradient: True
# Layer: module.feature.block4.0.1.bn1.weight, Requires Gradient: True
# Layer: module.feature.block4.0.1.bn1.bias, Requires Gradient: True
# Layer: module.feature.block4.0.1.conv_dw.weight, Requires Gradient: True
# Layer: module.feature.block4.0.1.bn2.weight, Requires Gradient: True
# Layer: module.feature.block4.0.1.bn2.bias, Requires Gradient: True
# Layer: module.feature.block4.0.1.conv_pwl.weight, Requires Gradient: True
# Layer: module.feature.block4.0.1.bn3.weight, Requires Gradient: True
# Layer: module.feature.block4.0.1.bn3.bias, Requires Gradient: True
# Layer: module.feature.block4.0.2.conv_pw.weight, Requires Gradient: True
# Layer: module.feature.block4.0.2.bn1.weight, Requires Gradient: True
# Layer: module.feature.block4.0.2.bn1.bias, Requires Gradient: True
# Layer: module.feature.block4.0.2.conv_dw.weight, Requires Gradient: True
# Layer: module.feature.block4.0.2.bn2.weight, Requires Gradient: True
# Layer: module.feature.block4.0.2.bn2.bias, Requires Gradient: True
# Layer: module.feature.block4.0.2.conv_pwl.weight, Requires Gradient: True
# Layer: module.feature.block4.0.2.bn3.weight, Requires Gradient: True
# Layer: module.feature.block4.0.2.bn3.bias, Requires Gradient: True
# Layer: module.feature_up.deconv32_16.conv1.conv.weight, Requires Gradient: True
# Layer: module.feature_up.deconv32_16.conv1.bn.weight, Requires Gradient: True
# Layer: module.feature_up.deconv32_16.conv1.bn.bias, Requires Gradient: True
# Layer: module.feature_up.deconv32_16.conv2.conv.weight, Requires Gradient: True
# Layer: module.feature_up.deconv32_16.conv2.bn.weight, Requires Gradient: True
# Layer: module.feature_up.deconv32_16.conv2.bn.bias, Requires Gradient: True
# Layer: module.feature_up.deconv16_8.conv1.conv.weight, Requires Gradient: True
# Layer: module.feature_up.deconv16_8.conv1.bn.weight, Requires Gradient: True
# Layer: module.feature_up.deconv16_8.conv1.bn.bias, Requires Gradient: True
# Layer: module.feature_up.deconv16_8.conv2.conv.weight, Requires Gradient: True
# Layer: module.feature_up.deconv16_8.conv2.bn.weight, Requires Gradient: True
# Layer: module.feature_up.deconv16_8.conv2.bn.bias, Requires Gradient: True
# Layer: module.feature_up.deconv8_4.conv1.conv.weight, Requires Gradient: True
# Layer: module.feature_up.deconv8_4.conv1.bn.weight, Requires Gradient: True
# Layer: module.feature_up.deconv8_4.conv1.bn.bias, Requires Gradient: True
# Layer: module.feature_up.deconv8_4.conv2.conv.weight, Requires Gradient: True
# Layer: module.feature_up.deconv8_4.conv2.bn.weight, Requires Gradient: True
# Layer: module.feature_up.deconv8_4.conv2.bn.bias, Requires Gradient: True
# Layer: module.feature_up.conv4.conv.weight, Requires Gradient: True
# Layer: module.feature_up.conv4.bn.weight, Requires Gradient: True
# Layer: module.feature_up.conv4.bn.bias, Requires Gradient: True
# Layer: module.patch.weight, Requires Gradient: True
# Layer: module.stem_2.0.conv.weight, Requires Gradient: True
# Layer: module.stem_2.0.bn.weight, Requires Gradient: True
# Layer: module.stem_2.0.bn.bias, Requires Gradient: True
# Layer: module.stem_2.1.weight, Requires Gradient: True
# Layer: module.stem_2.2.weight, Requires Gradient: True
# Layer: module.stem_2.2.bias, Requires Gradient: True
# Layer: module.stem_4.0.conv.weight, Requires Gradient: True
# Layer: module.stem_4.0.bn.weight, Requires Gradient: True
# Layer: module.stem_4.0.bn.bias, Requires Gradient: True
# Layer: module.stem_4.1.weight, Requires Gradient: True
# Layer: module.stem_4.2.weight, Requires Gradient: True
# Layer: module.stem_4.2.bias, Requires Gradient: True
# Layer: module.stem_8.0.conv.weight, Requires Gradient: True
# Layer: module.stem_8.0.bn.weight, Requires Gradient: True
# Layer: module.stem_8.0.bn.bias, Requires Gradient: True
# Layer: module.stem_8.1.weight, Requires Gradient: True
# Layer: module.stem_8.2.weight, Requires Gradient: True
# Layer: module.stem_8.2.bias, Requires Gradient: True
# Layer: module.concat_feature.0.conv.weight, Requires Gradient: True
# Layer: module.concat_feature.0.bn.weight, Requires Gradient: True
# Layer: module.concat_feature.0.bn.bias, Requires Gradient: True
# Layer: module.concat_feature.1.weight, Requires Gradient: True
# Layer: module.spx.0.weight, Requires Gradient: True
# Layer: module.spx.0.bias, Requires Gradient: True
# Layer: module.spx_2.conv1.conv.weight, Requires Gradient: True
# Layer: module.spx_2.conv1.bn.weight, Requires Gradient: True
# Layer: module.spx_2.conv1.bn.bias, Requires Gradient: True
# Layer: module.spx_2.conv2.conv.weight, Requires Gradient: True
# Layer: module.spx_2.conv2.bn.weight, Requires Gradient: True
# Layer: module.spx_2.conv2.bn.bias, Requires Gradient: True
# Layer: module.spx_4.0.conv.weight, Requires Gradient: True
# Layer: module.spx_4.0.bn.weight, Requires Gradient: True
# Layer: module.spx_4.0.bn.bias, Requires Gradient: True
# Layer: module.spx_4.1.weight, Requires Gradient: True
# Layer: module.spx_4.2.weight, Requires Gradient: True
# Layer: module.spx_4.2.bias, Requires Gradient: True
# Layer: module.corr_feature_att_8.im_att.0.conv.weight, Requires Gradient: True
# Layer: module.corr_feature_att_8.im_att.0.bn.weight, Requires Gradient: True
# Layer: module.corr_feature_att_8.im_att.0.bn.bias, Requires Gradient: True
# Layer: module.corr_feature_att_8.im_att.1.weight, Requires Gradient: True
# Layer: module.corr_feature_att_8.im_att.1.bias, Requires Gradient: True
# Layer: module.concat_feature_att_4.im_att.0.conv.weight, Requires Gradient: True
# Layer: module.concat_feature_att_4.im_att.0.bn.weight, Requires Gradient: True
# Layer: module.concat_feature_att_4.im_att.0.bn.bias, Requires Gradient: True
# Layer: module.concat_feature_att_4.im_att.1.weight, Requires Gradient: True
# Layer: module.concat_feature_att_4.im_att.1.bias, Requires Gradient: True
# Layer: module.hourglass_att.conv1.0.conv.weight, Requires Gradient: True
# Layer: module.hourglass_att.conv1.0.bn.weight, Requires Gradient: True
# Layer: module.hourglass_att.conv1.0.bn.bias, Requires Gradient: True
# Layer: module.hourglass_att.conv1.1.conv.weight, Requires Gradient: True
# Layer: module.hourglass_att.conv1.1.bn.weight, Requires Gradient: True
# Layer: module.hourglass_att.conv1.1.bn.bias, Requires Gradient: True
# Layer: module.hourglass_att.conv2.0.conv.weight, Requires Gradient: True
# Layer: module.hourglass_att.conv2.0.bn.weight, Requires Gradient: True
# Layer: module.hourglass_att.conv2.0.bn.bias, Requires Gradient: True
# Layer: module.hourglass_att.conv2.1.conv.weight, Requires Gradient: True
# Layer: module.hourglass_att.conv2.1.bn.weight, Requires Gradient: True
# Layer: module.hourglass_att.conv2.1.bn.bias, Requires Gradient: True
# Layer: module.hourglass_att.conv2_up.conv.weight, Requires Gradient: True
# Layer: module.hourglass_att.conv2_up.bn.weight, Requires Gradient: True
# Layer: module.hourglass_att.conv2_up.bn.bias, Requires Gradient: True
# Layer: module.hourglass_att.conv1_up_.conv.weight, Requires Gradient: True
# Layer: module.hourglass_att.conv1_up_.bn.weight, Requires Gradient: True
# Layer: module.hourglass_att.conv1_up_.bn.bias, Requires Gradient: True
# Layer: module.hourglass_att.conv_final.weight, Requires Gradient: True
# Layer: module.hourglass_att.agg.0.conv.weight, Requires Gradient: True
# Layer: module.hourglass_att.agg.0.bn.weight, Requires Gradient: True
# Layer: module.hourglass_att.agg.0.bn.bias, Requires Gradient: True
# Layer: module.hourglass_att.agg.1.conv.weight, Requires Gradient: True
# Layer: module.hourglass_att.agg.1.bn.weight, Requires Gradient: True
# Layer: module.hourglass_att.agg.1.bn.bias, Requires Gradient: True
# Layer: module.hourglass_att.agg.2.conv.weight, Requires Gradient: True
# Layer: module.hourglass_att.agg.2.bn.weight, Requires Gradient: True
# Layer: module.hourglass_att.agg.2.bn.bias, Requires Gradient: True
# Layer: module.hourglass_att.feature_att_16.im_att.0.conv.weight, Requires Gradient: True
# Layer: module.hourglass_att.feature_att_16.im_att.0.bn.weight, Requires Gradient: True
# Layer: module.hourglass_att.feature_att_16.im_att.0.bn.bias, Requires Gradient: True
# Layer: module.hourglass_att.feature_att_16.im_att.1.weight, Requires Gradient: True
# Layer: module.hourglass_att.feature_att_16.im_att.1.bias, Requires Gradient: True
# Layer: module.hourglass_att.feature_att_32.im_att.0.conv.weight, Requires Gradient: True
# Layer: module.hourglass_att.feature_att_32.im_att.0.bn.weight, Requires Gradient: True
# Layer: module.hourglass_att.feature_att_32.im_att.0.bn.bias, Requires Gradient: True
# Layer: module.hourglass_att.feature_att_32.im_att.1.weight, Requires Gradient: True
# Layer: module.hourglass_att.feature_att_32.im_att.1.bias, Requires Gradient: True
# Layer: module.hourglass_att.feature_att_up_16.im_att.0.conv.weight, Requires Gradient: True
# Layer: module.hourglass_att.feature_att_up_16.im_att.0.bn.weight, Requires Gradient: True
# Layer: module.hourglass_att.feature_att_up_16.im_att.0.bn.bias, Requires Gradient: True
# Layer: module.hourglass_att.feature_att_up_16.im_att.1.weight, Requires Gradient: True
# Layer: module.hourglass_att.feature_att_up_16.im_att.1.bias, Requires Gradient: True
# Layer: module.hourglass.conv1.0.conv.weight, Requires Gradient: True
# Layer: module.hourglass.conv1.0.bn.weight, Requires Gradient: True
# Layer: module.hourglass.conv1.0.bn.bias, Requires Gradient: True
# Layer: module.hourglass.conv1.1.conv.weight, Requires Gradient: True
# Layer: module.hourglass.conv1.1.bn.weight, Requires Gradient: True
# Layer: module.hourglass.conv1.1.bn.bias, Requires Gradient: True
# Layer: module.hourglass.conv2.0.conv.weight, Requires Gradient: True
# Layer: module.hourglass.conv2.0.bn.weight, Requires Gradient: True
# Layer: module.hourglass.conv2.0.bn.bias, Requires Gradient: True
# Layer: module.hourglass.conv2.1.conv.weight, Requires Gradient: True
# Layer: module.hourglass.conv2.1.bn.weight, Requires Gradient: True
# Layer: module.hourglass.conv2.1.bn.bias, Requires Gradient: True
# Layer: module.hourglass.conv2_up.conv.weight, Requires Gradient: True
# Layer: module.hourglass.conv2_up.bn.weight, Requires Gradient: True
# Layer: module.hourglass.conv2_up.bn.bias, Requires Gradient: True
# Layer: module.hourglass.conv1_up.conv.weight, Requires Gradient: True
# Layer: module.hourglass.conv1_up.bn.weight, Requires Gradient: True
# Layer: module.hourglass.conv1_up.bn.bias, Requires Gradient: True
# Layer: module.hourglass.agg.0.conv.weight, Requires Gradient: True
# Layer: module.hourglass.agg.0.bn.weight, Requires Gradient: True
# Layer: module.hourglass.agg.0.bn.bias, Requires Gradient: True
# Layer: module.hourglass.agg.1.conv.weight, Requires Gradient: True
# Layer: module.hourglass.agg.1.bn.weight, Requires Gradient: True
# Layer: module.hourglass.agg.1.bn.bias, Requires Gradient: True
# Layer: module.hourglass.agg.2.conv.weight, Requires Gradient: True
# Layer: module.hourglass.agg.2.bn.weight, Requires Gradient: True
# Layer: module.hourglass.agg.2.bn.bias, Requires Gradient: True
# Layer: module.hourglass.feature_att_8.im_att.0.conv.weight, Requires Gradient: True
# Layer: module.hourglass.feature_att_8.im_att.0.bn.weight, Requires Gradient: True
# Layer: module.hourglass.feature_att_8.im_att.0.bn.bias, Requires Gradient: True
# Layer: module.hourglass.feature_att_8.im_att.1.weight, Requires Gradient: True
# Layer: module.hourglass.feature_att_8.im_att.1.bias, Requires Gradient: True
# Layer: module.hourglass.feature_att_16.im_att.0.conv.weight, Requires Gradient: True
# Layer: module.hourglass.feature_att_16.im_att.0.bn.weight, Requires Gradient: True
# Layer: module.hourglass.feature_att_16.im_att.0.bn.bias, Requires Gradient: True
# Layer: module.hourglass.feature_att_16.im_att.1.weight, Requires Gradient: True
# Layer: module.hourglass.feature_att_16.im_att.1.bias, Requires Gradient: True
# Layer: module.hourglass.feature_att_up_8.im_att.0.conv.weight, Requires Gradient: True
# Layer: module.hourglass.feature_att_up_8.im_att.0.bn.weight, Requires Gradient: True
# Layer: module.hourglass.feature_att_up_8.im_att.0.bn.bias, Requires Gradient: True
# Layer: module.hourglass.feature_att_up_8.im_att.1.weight, Requires Gradient: True
# Layer: module.hourglass.feature_att_up_8.im_att.1.bias, Requires Gradient: True
# Layer: module.concat_stem.conv.weight, Requires Gradient: True
# Layer: module.concat_stem.bn.weight, Requires Gradient: True
# Layer: module.concat_stem.bn.bias, Requires Gradient: True

# %%
# Cargar un checkpoint para evaluar
ckpt_path = '/content/Depth-Estimation-with-StereoThermal-Images/pretrained_model/trained_without_freezing_f2h4_e24.ckpt' # Cambiar segun el ckpt que se desee probar
if ckpt_path is not None:
    print("loading model {}".format(ckpt_path))
    state_dict = torch.load(ckpt_path)
    model_dict = model.state_dict()
    pre_dict = {k: v for k, v in state_dict['model'].items() if k in model_dict}
    model_dict.update(pre_dict)
    model.load_state_dict(model_dict)
# Out:
# loading model /content/Depth-Estimation-with-StereoThermal-Images/pretrained_model/trained_without_freezing_f2h4_e24.ckpt

# %%
# Carga de datos
from torch.utils.data import ConcatDataset, DataLoader
# Dataset validacion
dataset_frick_test = ThermalStereoDataset(root_dir='/content/drive/MyDrive/Procesamiento de imagenes/Proyecto Final/dataset', domain='frick_2', split='test', training=False)
dataset_hawkins_test = ThermalStereoDataset(root_dir='/content/drive/MyDrive/Procesamiento de imagenes/Proyecto Final/dataset', domain='hawkins_4', split='test', training=False)
combined_dataset_test = ConcatDataset([dataset_frick_test, dataset_hawkins_test])
test_loader = DataLoader(combined_dataset_test, batch_size=4, shuffle=False, num_workers=4)

def test():
    # # testing
    avg_test_scalars = AverageMeterDict()
    for batch_idx, sample in enumerate(test_loader):
        start_time = time.time()
        loss, scalar_outputs = test_sample(sample)
        avg_test_scalars.update(scalar_outputs)

        del scalar_outputs
        print('Iter {}/{}, test loss = {:.3f}, time = {:3f}'.format(batch_idx,
                                                                    len(test_loader), loss,
                                                                    time.time() - start_time))
    avg_test_scalars = avg_test_scalars.mean()
    print("avg_test_scalars", avg_test_scalars)
    gc.collect()

# test one sample
@make_nograd_func
def test_sample(sample):
    model.eval()
    imgL, imgR, disp_gt = sample['left'], sample['right'], sample['disparity']
    imgL = imgL.cuda()
    imgR = imgR.cuda()
    disp_gt = disp_gt.cuda()
    mask = (disp_gt < 192) & (disp_gt > 0)
    disp_ests = model(imgL, imgR)
    disp_gts = [disp_gt]
    masks = [mask]
    loss = model_loss_test(disp_ests, disp_gts, masks)

    scalar_outputs = {"loss": loss}
    scalar_outputs["D1"] = [D1_metric(disp_est, disp_gt, mask) for disp_est in disp_ests]
    scalar_outputs["EPE"] = [EPE_metric(disp_est, disp_gt, mask) for disp_est in disp_ests]
    scalar_outputs["Thres1"] = [Thres_metric(disp_est, disp_gt, mask, 1.0) for disp_est in disp_ests]
    scalar_outputs["Thres2"] = [Thres_metric(disp_est, disp_gt, mask, 2.0) for disp_est in disp_ests]
    scalar_outputs["Thres3"] = [Thres_metric(disp_est, disp_gt, mask, 3.0) for disp_est in disp_ests]

    return tensor2float(loss), tensor2float(scalar_outputs)

if __name__ == '__main__':
    test()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/functional.py:539: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:3637.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /usr/local/lib/python3.11/dist-packages/torch/nn/_reduction.py:51: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))
# Iter 0/281, test loss = 2.908, time = 8.252657
# Iter 1/281, test loss = 3.026, time = 0.217919
# Iter 2/281, test loss = 2.383, time = 0.221564
# Iter 3/281, test loss = 2.389, time = 0.220053
# Iter 4/281, test loss = 2.398, time = 0.207241
# Iter 5/281, test loss = 2.571, time = 0.205611
# Iter 6/281, test loss = 2.826, time = 0.210634
# Iter 7/281, test loss = 3.320, time = 0.209616
# Iter 8/281, test loss = 4.021, time = 0.276955
# Iter 9/281, test loss = 4.360, time = 0.218147
# Iter 10/281, test loss = 4.812, time = 0.203955
# Iter 11/281, test loss = 5.512, time = 0.204116
# Iter 12/281, test loss = 6.383, time = 0.293719
# Iter 13/281, test loss = 7.995, time = 0.205002
# Iter 14/281, test loss = 8.706, time = 0.210186
# Iter 15/281, test loss = 9.891, time = 0.203000
# Iter 16/281, test loss = 10.203, time = 0.290401
# Iter 17/281, test loss = 10.321, time = 0.233169
# Iter 18/281, test loss = 9.886, time = 0.231050
# Iter 19/281, test loss = 10.853, time = 0.210377
# Iter 20/281, test loss = 12.409, time = 0.289536
# Iter 21/281, test loss = 13.190, time = 0.210137
# Iter 22/281, test loss = 11.699, time = 0.203926
# Iter 23/281, test loss = 10.772, time = 0.209031
# Iter 24/281, test loss = 9.880, time = 0.286859
# Iter 25/281, test loss = 13.242, time = 0.209016
# Iter 26/281, test loss = 18.203, time = 0.204345
# Iter 27/281, test loss = 19.855, time = 0.207165
# Iter 28/281, test loss = 19.092, time = 0.280726
# Iter 29/281, test loss = 19.969, time = 0.203307
# Iter 30/281, test loss = 23.264, time = 0.202994
# Iter 31/281, test loss = 23.035, time = 0.206136
# Iter 32/281, test loss = 20.606, time = 0.298467
# Iter 33/281, test loss = 17.926, time = 0.212308
# Iter 34/281, test loss = 11.487, time = 0.210963
# Iter 35/281, test loss = 9.870, time = 0.205264
# Iter 36/281, test loss = 8.701, time = 0.307244
# Iter 37/281, test loss = 5.253, time = 0.234899
# Iter 38/281, test loss = 6.452, time = 0.265459
# Iter 39/281, test loss = 5.566, time = 0.299207
# Iter 40/281, test loss = 5.040, time = 0.211925
# Iter 41/281, test loss = 4.990, time = 0.201777
# Iter 42/281, test loss = 4.207, time = 0.211581
# Iter 43/281, test loss = 4.726, time = 0.258589
# Iter 44/281, test loss = 5.140, time = 0.220011
# Iter 45/281, test loss = 6.855, time = 0.215239
# Iter 46/281, test loss = 7.534, time = 0.207136
# Iter 47/281, test loss = 9.249, time = 0.281567
# Iter 48/281, test loss = 13.472, time = 0.217587
# Iter 49/281, test loss = 13.671, time = 0.236655
# Iter 50/281, test loss = 12.026, time = 0.212647
# Iter 51/281, test loss = 13.207, time = 0.285290
# Iter 52/281, test loss = 10.966, time = 0.211438
# Iter 53/281, test loss = 4.672, time = 0.211847
# Iter 54/281, test loss = 4.079, time = 0.207074
# Iter 55/281, test loss = 4.104, time = 0.328290
# Iter 56/281, test loss = 4.381, time = 0.206434
# Iter 57/281, test loss = 4.347, time = 0.208644
# Iter 58/281, test loss = 3.695, time = 0.212011
# Iter 59/281, test loss = 3.718, time = 0.291954
# Iter 60/281, test loss = 3.749, time = 0.208396
# Iter 61/281, test loss = 3.753, time = 0.204778
# Iter 62/281, test loss = 3.922, time = 0.207731
# Iter 63/281, test loss = 4.631, time = 0.309797
# Iter 64/281, test loss = 5.559, time = 0.214882
# Iter 65/281, test loss = 9.311, time = 0.286816
# Iter 66/281, test loss = 9.279, time = 0.207557
# Iter 67/281, test loss = 4.492, time = 0.210382
# Iter 68/281, test loss = 3.299, time = 0.213186
# Iter 69/281, test loss = 3.085, time = 0.313528
# Iter 70/281, test loss = 3.109, time = 0.260456
# Iter 71/281, test loss = 4.058, time = 0.217884
# Iter 72/281, test loss = 5.070, time = 0.208577
# Iter 73/281, test loss = 3.451, time = 0.209699
# Iter 74/281, test loss = 2.145, time = 0.286082
# Iter 75/281, test loss = 2.190, time = 0.208180
# Iter 76/281, test loss = 1.665, time = 0.214877
# Iter 77/281, test loss = 1.718, time = 0.300124
# Iter 78/281, test loss = 2.122, time = 0.297295
# Iter 79/281, test loss = 2.109, time = 0.212457
# Iter 80/281, test loss = 1.898, time = 0.210563
# Iter 81/281, test loss = 2.179, time = 0.275744
# Iter 82/281, test loss = 2.526, time = 0.294394
# Iter 83/281, test loss = 2.566, time = 0.208000
# Iter 84/281, test loss = 2.658, time = 0.207437
# Iter 85/281, test loss = 2.611, time = 0.220628
# Iter 86/281, test loss = 2.889, time = 0.263594
# Iter 87/281, test loss = 2.846, time = 0.221748
# Iter 88/281, test loss = 3.245, time = 0.232843
# Iter 89/281, test loss = 3.472, time = 0.213815
# Iter 90/281, test loss = 2.958, time = 0.298878
# Iter 91/281, test loss = 2.308, time = 0.210374
# Iter 92/281, test loss = 2.173, time = 0.217911
# Iter 93/281, test loss = 3.020, time = 0.272892
# Iter 94/281, test loss = 2.921, time = 0.261365
# Iter 95/281, test loss = 2.247, time = 0.218714
# Iter 96/281, test loss = 2.274, time = 0.212167
# Iter 97/281, test loss = 2.491, time = 0.299499
# Iter 98/281, test loss = 2.982, time = 0.307951
# Iter 99/281, test loss = 3.001, time = 0.207935
# Iter 100/281, test loss = 2.862, time = 0.217240
# Iter 101/281, test loss = 2.498, time = 0.282492
# Iter 102/281, test loss = 2.244, time = 0.260636
# Iter 103/281, test loss = 2.380, time = 0.217256
# Iter 104/281, test loss = 2.636, time = 0.215255
# Iter 105/281, test loss = 2.332, time = 0.282200
# Iter 106/281, test loss = 2.518, time = 0.213035
# Iter 107/281, test loss = 2.425, time = 0.208606
# Iter 108/281, test loss = 2.280, time = 0.215972
# Iter 109/281, test loss = 2.302, time = 0.262069
# Iter 110/281, test loss = 2.400, time = 0.211666
# Iter 111/281, test loss = 2.701, time = 0.211558
# Iter 112/281, test loss = 2.603, time = 0.223839
# Iter 113/281, test loss = 2.633, time = 0.277053
# Iter 114/281, test loss = 2.829, time = 0.212932
# Iter 115/281, test loss = 2.604, time = 0.216709
# Iter 116/281, test loss = 2.766, time = 0.224536
# Iter 117/281, test loss = 2.782, time = 0.296579
# Iter 118/281, test loss = 2.879, time = 0.281897
# Iter 119/281, test loss = 2.681, time = 0.217937
# Iter 120/281, test loss = 2.607, time = 0.217037
# Iter 121/281, test loss = 2.492, time = 0.263917
# Iter 122/281, test loss = 2.554, time = 0.267236
# Iter 123/281, test loss = 2.531, time = 0.214850
# Iter 124/281, test loss = 2.390, time = 0.214339
# Iter 125/281, test loss = 2.373, time = 0.261120
# Iter 126/281, test loss = 2.288, time = 0.282490
# Iter 127/281, test loss = 2.502, time = 0.209157
# Iter 128/281, test loss = 2.303, time = 0.211060
# Iter 129/281, test loss = 2.288, time = 0.265181
# Iter 130/281, test loss = 2.226, time = 0.286878
# Iter 131/281, test loss = 2.264, time = 0.224070
# Iter 132/281, test loss = 2.299, time = 0.214834
# Iter 133/281, test loss = 2.034, time = 0.302197
# Iter 134/281, test loss = 2.121, time = 0.265102
# Iter 135/281, test loss = 2.301, time = 0.217743
# Iter 136/281, test loss = 2.083, time = 0.211395
# Iter 137/281, test loss = 2.106, time = 0.303852
# Iter 138/281, test loss = 2.008, time = 0.289150
# Iter 139/281, test loss = 2.223, time = 0.227482
# Iter 140/281, test loss = 2.152, time = 0.228026
# Iter 141/281, test loss = 2.111, time = 0.214393
# Iter 142/281, test loss = 2.447, time = 0.297978
# Iter 143/281, test loss = 2.541, time = 0.212817
# Iter 144/281, test loss = 2.447, time = 0.213390
# Iter 145/281, test loss = 2.444, time = 0.261944
# Iter 146/281, test loss = 2.247, time = 0.219853
# Iter 147/281, test loss = 2.642, time = 0.220456
# Iter 148/281, test loss = 2.191, time = 0.243205
# Iter 149/281, test loss = 2.470, time = 0.279545
# Iter 150/281, test loss = 2.314, time = 0.265567
# Iter 151/281, test loss = 2.187, time = 0.225702
# Iter 152/281, test loss = 2.133, time = 0.215018
# Iter 153/281, test loss = 2.335, time = 0.304355
# Iter 154/281, test loss = 2.277, time = 0.226912
# Iter 155/281, test loss = 2.221, time = 0.248522
# Iter 156/281, test loss = 2.344, time = 0.248370
# Iter 157/281, test loss = 2.346, time = 0.280463
# Iter 158/281, test loss = 2.332, time = 0.212368
# Iter 159/281, test loss = 2.404, time = 0.216850
# Iter 160/281, test loss = 2.891, time = 0.213388
# Iter 161/281, test loss = 2.718, time = 0.298410
# Iter 162/281, test loss = 2.708, time = 0.225191
# Iter 163/281, test loss = 2.749, time = 0.242823
# Iter 164/281, test loss = 2.810, time = 0.218870
# Iter 165/281, test loss = 2.926, time = 0.271084
# Iter 166/281, test loss = 3.183, time = 0.233069
# Iter 167/281, test loss = 2.779, time = 0.216639
# Iter 168/281, test loss = 2.675, time = 0.217279
# Iter 169/281, test loss = 3.049, time = 0.284923
# Iter 170/281, test loss = 2.993, time = 0.214825
# Iter 171/281, test loss = 3.020, time = 0.215054
# Iter 172/281, test loss = 2.260, time = 0.224476
# Iter 173/281, test loss = 2.325, time = 0.265827
# Iter 174/281, test loss = 2.329, time = 0.220046
# Iter 175/281, test loss = 2.552, time = 0.216071
# Iter 176/281, test loss = 2.458, time = 0.212141
# Iter 177/281, test loss = 2.201, time = 0.277004
# Iter 178/281, test loss = 2.152, time = 0.212610
# Iter 179/281, test loss = 2.136, time = 0.216853
# Iter 180/281, test loss = 2.617, time = 0.217535
# Iter 181/281, test loss = 2.049, time = 0.261136
# Iter 182/281, test loss = 2.335, time = 0.220940
# Iter 183/281, test loss = 2.250, time = 0.213388
# Iter 184/281, test loss = 1.845, time = 0.231279
# Iter 185/281, test loss = 2.863, time = 0.296931
# Iter 186/281, test loss = 2.473, time = 0.219420
# Iter 187/281, test loss = 2.165, time = 0.219831
# Iter 188/281, test loss = 2.217, time = 0.214890
# Iter 189/281, test loss = 1.980, time = 0.264363
# Iter 190/281, test loss = 2.140, time = 0.240368
# Iter 191/281, test loss = 2.058, time = 0.226319
# Iter 192/281, test loss = 1.935, time = 0.232096
# Iter 193/281, test loss = 2.116, time = 0.267920
# Iter 194/281, test loss = 2.090, time = 0.223337
# Iter 195/281, test loss = 2.329, time = 0.213530
# Iter 196/281, test loss = 2.226, time = 0.213119
# Iter 197/281, test loss = 2.710, time = 0.276200
# Iter 198/281, test loss = 2.881, time = 0.216847
# Iter 199/281, test loss = 2.030, time = 0.221915
# Iter 200/281, test loss = 1.980, time = 0.230166
# Iter 201/281, test loss = 2.049, time = 0.295471
# Iter 202/281, test loss = 1.936, time = 0.220103
# Iter 203/281, test loss = 1.679, time = 0.212683
# Iter 204/281, test loss = 1.846, time = 0.216443
# Iter 205/281, test loss = 1.893, time = 0.269566
# Iter 206/281, test loss = 1.859, time = 0.229135
# Iter 207/281, test loss = 1.713, time = 0.236560
# Iter 208/281, test loss = 1.629, time = 0.272667
# Iter 209/281, test loss = 1.578, time = 0.291658
# Iter 210/281, test loss = 1.640, time = 0.212606
# Iter 211/281, test loss = 1.479, time = 0.218410
# Iter 212/281, test loss = 1.500, time = 0.218205
# Iter 213/281, test loss = 1.525, time = 0.329129
# Iter 214/281, test loss = 1.854, time = 0.225360
# Iter 215/281, test loss = 2.228, time = 0.225244
# Iter 216/281, test loss = 2.242, time = 0.214221
# Iter 217/281, test loss = 2.492, time = 0.349434
# Iter 218/281, test loss = 3.280, time = 0.219464
# Iter 219/281, test loss = 4.051, time = 0.224713
# Iter 220/281, test loss = 2.543, time = 0.217562
# Iter 221/281, test loss = 2.695, time = 0.269540
# Iter 222/281, test loss = 3.052, time = 0.244325
# Iter 223/281, test loss = 1.800, time = 0.240106
# Iter 224/281, test loss = 2.955, time = 0.220588
# Iter 225/281, test loss = 3.447, time = 0.310926
# Iter 226/281, test loss = 3.597, time = 0.218004
# Iter 227/281, test loss = 3.737, time = 0.214555
# Iter 228/281, test loss = 3.393, time = 0.217786
# Iter 229/281, test loss = 3.839, time = 0.278841
# Iter 230/281, test loss = 3.771, time = 0.213589
# Iter 231/281, test loss = 4.198, time = 0.216851
# Iter 232/281, test loss = 3.837, time = 0.219575
# Iter 233/281, test loss = 3.762, time = 0.295019
# Iter 234/281, test loss = 3.596, time = 0.236761
# Iter 235/281, test loss = 3.632, time = 0.255531
# Iter 236/281, test loss = 3.677, time = 0.223388
# Iter 237/281, test loss = 3.556, time = 0.279836
# Iter 238/281, test loss = 3.454, time = 0.275770
# Iter 239/281, test loss = 3.000, time = 0.223000
# Iter 240/281, test loss = 1.799, time = 0.218097
# Iter 241/281, test loss = 1.990, time = 0.315253
# Iter 242/281, test loss = 2.101, time = 0.304735
# Iter 243/281, test loss = 2.216, time = 0.216823
# Iter 244/281, test loss = 2.099, time = 0.216471
# Iter 245/281, test loss = 2.094, time = 0.306127
# Iter 246/281, test loss = 2.315, time = 0.296872
# Iter 247/281, test loss = 2.068, time = 0.220586
# Iter 248/281, test loss = 2.198, time = 0.218439
# Iter 249/281, test loss = 2.132, time = 0.260795
# Iter 250/281, test loss = 2.897, time = 0.271215
# Iter 251/281, test loss = 2.261, time = 0.224187
# Iter 252/281, test loss = 2.061, time = 0.221861
# Iter 253/281, test loss = 2.248, time = 0.270292
# Iter 254/281, test loss = 2.239, time = 0.264539
# Iter 255/281, test loss = 2.213, time = 0.222350
# Iter 256/281, test loss = 2.128, time = 0.218807
# Iter 257/281, test loss = 2.183, time = 0.257669
# Iter 258/281, test loss = 2.499, time = 0.300555
# Iter 259/281, test loss = 2.470, time = 0.222273
# Iter 260/281, test loss = 2.452, time = 0.216272
# Iter 261/281, test loss = 2.873, time = 0.239527
# Iter 262/281, test loss = 2.613, time = 0.298267
# Iter 263/281, test loss = 2.692, time = 0.215868
# Iter 264/281, test loss = 2.173, time = 0.215481
# Iter 265/281, test loss = 2.290, time = 0.215313
# Iter 266/281, test loss = 2.378, time = 0.313186
# Iter 267/281, test loss = 2.375, time = 0.225052
# Iter 268/281, test loss = 2.305, time = 0.229893
# Iter 269/281, test loss = 2.374, time = 0.215580
# Iter 270/281, test loss = 2.458, time = 0.279087
# Iter 271/281, test loss = 2.542, time = 0.242900
# Iter 272/281, test loss = 2.659, time = 0.251535
# Iter 273/281, test loss = 2.706, time = 0.217463
# Iter 274/281, test loss = 2.364, time = 0.307146
# Iter 275/281, test loss = 2.661, time = 0.216812
# Iter 276/281, test loss = 2.936, time = 0.222000
# Iter 277/281, test loss = 3.236, time = 0.223100
# Iter 278/281, test loss = 3.333, time = 0.289236
# Iter 279/281, test loss = 3.302, time = 0.226910
# Iter 280/281, test loss = 4.310, time = 2.226631
# avg_test_scalars {'loss': 3.981109223331845, 'D1': [0.20935493064679708], 'EPE': [3.9818400878498985], 'Thres1': [0.6398537677590109], 'Thres2': [0.4091137772247036], 'Thres3': [0.27632080076852306]}
